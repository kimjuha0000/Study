# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjuha0000/Stat_study/blob/main/%EC%A3%BC%EA%B0%80%EB%8D%B0%EC%9D%B4%ED%84%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/data_1242_20250118.csv', encoding = 'cp949')
df
# Out:
#              일자     종가    대비   등락률     시가     고가     저가       거래량  \
# 0    2025/01/17  53700  -600 -1.10  53800  54100  53200  18805344
# 1    2025/01/16  54300   600  1.12  54200  55000  54100  18627298
# 2    2025/01/15  53700  -200 -0.37  54100  54700  53500  18625025
# 3    2025/01/14  53900  -200 -0.37  54200  54600  53700  17465926
# 4    2025/01/13  54100 -1200 -2.17  54600  55000  54100  16868600
# ..          ...    ...   ...   ...    ...    ...    ...       ...
# 240  2024/01/23  75200   100  0.13  75700  75800  74300  14786224
# 241  2024/01/22  75100   400  0.54  75900  76000  75000  19673375
# 242  2024/01/19  74700  3000  4.18  73500  74700  73000  23363427
# 243  2024/01/18  71700   700  0.99  71600  72000  70700  17853397
# 244  2024/01/17  71000 -1600 -2.20  73100  73300  71000  22683660
#
#               거래대금             시가총액       상장주식수
# 0    1007047374200  320577322935000  5969782550
# 1    1014922869739  324159192465000  5969782550
# ...

# %%
df.head(3)
# Out:
#            일자     종가   대비   등락률     시가     고가     저가       거래량           거래대금  \
# 0  2025/01/17  53700 -600 -1.10  53800  54100  53200  18805344  1007047374200
# 1  2025/01/16  54300  600  1.12  54200  55000  54100  18627298  1014922869739
# 2  2025/01/15  53700 -200 -0.37  54100  54700  53500  18625025  1005085420250
#
#               시가총액       상장주식수
# 0  320577322935000  5969782550
# 1  324159192465000  5969782550
# 2  320577322935000  5969782550

# %%
df.shape
# Out:
# (245, 11)

# %%
df['거래대금'].head()
# Out:
# 0    1007047374200
# 1    1014922869739
# 2    1005085420250
# 3     944534229000
# 4     917178336730
# Name: 거래대금, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      245 non-null    object
#  1   종가      245 non-null    int64
#  2   대비      245 non-null    int64
#  3   등락률     245 non-null    float64
#  4   시가      245 non-null    int64
#  5   고가      245 non-null    int64
#  6   저가      245 non-null    int64
#  7   거래량     245 non-null    int64
#  8   거래대금    245 non-null    int64
#  9   시가총액    245 non-null    int64
#  10  상장주식수   245 non-null    int64
# dtypes: float64(1), int64(9), object(1)
# memory usage: 21.2+ KB

# %%
df.rename(columns = {'일자':'date'}, inplace = True)

# %%
df
# Out:
#            date     종가    대비   등락률     시가     고가     저가       거래량  \
# 0    2025/01/17  53700  -600 -1.10  53800  54100  53200  18805344
# 1    2025/01/16  54300   600  1.12  54200  55000  54100  18627298
# 2    2025/01/15  53700  -200 -0.37  54100  54700  53500  18625025
# 3    2025/01/14  53900  -200 -0.37  54200  54600  53700  17465926
# 4    2025/01/13  54100 -1200 -2.17  54600  55000  54100  16868600
# ..          ...    ...   ...   ...    ...    ...    ...       ...
# 240  2024/01/23  75200   100  0.13  75700  75800  74300  14786224
# 241  2024/01/22  75100   400  0.54  75900  76000  75000  19673375
# 242  2024/01/19  74700  3000  4.18  73500  74700  73000  23363427
# 243  2024/01/18  71700   700  0.99  71600  72000  70700  17853397
# 244  2024/01/17  71000 -1600 -2.20  73100  73300  71000  22683660
#
#               거래대금             시가총액       상장주식수
# 0    1007047374200  320577322935000  5969782550
# 1    1014922869739  324159192465000  5969782550
# ...

# %%
df.rename(columns = {'종가':'closing_price'}, inplace = True)

# %%
df
# Out:
#            date  closing_price    대비   등락률     시가     고가     저가       거래량  \
# 0    2025/01/17          53700  -600 -1.10  53800  54100  53200  18805344
# 1    2025/01/16          54300   600  1.12  54200  55000  54100  18627298
# 2    2025/01/15          53700  -200 -0.37  54100  54700  53500  18625025
# 3    2025/01/14          53900  -200 -0.37  54200  54600  53700  17465926
# 4    2025/01/13          54100 -1200 -2.17  54600  55000  54100  16868600
# ..          ...            ...   ...   ...    ...    ...    ...       ...
# 240  2024/01/23          75200   100  0.13  75700  75800  74300  14786224
# 241  2024/01/22          75100   400  0.54  75900  76000  75000  19673375
# 242  2024/01/19          74700  3000  4.18  73500  74700  73000  23363427
# 243  2024/01/18          71700   700  0.99  71600  72000  70700  17853397
# 244  2024/01/17          71000 -1600 -2.20  73100  73300  71000  22683660
#
#               거래대금             시가총액       상장주식수
# ...

# %%
df.rename(columns = {'대비':'change'}, inplace = True)

# %%
df.rename(columns = {'등락률':'fluctutation_rate'}, inplace = True)

# %%
df.rename(columns = {'시가':'opening_price','고가':'high_price'}, inplace = True)

# %%
df.rename(columns = {'저가':'low_price','거래량':'trading_volumne','거래대금':'trading_value','시가총액':'market_capitalization'}, inplace = True)

# %%
df.rename(columns = {'상장주식수':'number_of_listed_shares'}, inplace = True)

# %%
df
# Out:
#            date  closing_price  change  fluctutation_rate  opening_price  \
# 0    2025/01/17          53700    -600              -1.10          53800
# 1    2025/01/16          54300     600               1.12          54200
# 2    2025/01/15          53700    -200              -0.37          54100
# 3    2025/01/14          53900    -200              -0.37          54200
# 4    2025/01/13          54100   -1200              -2.17          54600
# ..          ...            ...     ...                ...            ...
# 240  2024/01/23          75200     100               0.13          75700
# 241  2024/01/22          75100     400               0.54          75900
# 242  2024/01/19          74700    3000               4.18          73500
# 243  2024/01/18          71700     700               0.99          71600
# 244  2024/01/17          71000   -1600              -2.20          73100
#
#      high_price  low_price  trading_volumne  trading_value  \
# ...

# %%
df.drop(columns = 'number_of_listed_shares', inplace = True)

# %%
df
# Out:
#            date  closing_price  change  fluctutation_rate  opening_price  \
# 0    2025/01/17          53700    -600              -1.10          53800
# 1    2025/01/16          54300     600               1.12          54200
# 2    2025/01/15          53700    -200              -0.37          54100
# 3    2025/01/14          53900    -200              -0.37          54200
# 4    2025/01/13          54100   -1200              -2.17          54600
# ..          ...            ...     ...                ...            ...
# 240  2024/01/23          75200     100               0.13          75700
# 241  2024/01/22          75100     400               0.54          75900
# 242  2024/01/19          74700    3000               4.18          73500
# 243  2024/01/18          71700     700               0.99          71600
# 244  2024/01/17          71000   -1600              -2.20          73100
#
#      high_price  low_price  trading_volumne  trading_value  \
# ...

# %%
column_to_delete = ['trading_value','market_capitalization','market_capitalization']
df.drop(columns = column_to_delete, inplace = True)

# %%
df.rename(columns ={'trading_volumne':'trading_volume'}, inplace = True)

# %%
df.sort_values(by = 'date', ascending = False, inplace = True)

# %%
df.sort_values(by = 'opening_price',ascending = True)
# Out:
#            date  closing_price  change  fluctutation_rate  opening_price  \
# 43   2024/11/14          49900    -700              -1.38          50200
# 42   2024/11/15          53500    3600               7.21          50300
# 44   2024/11/13          50600   -2400              -4.53          52000
# 29   2024/12/04          53100    -500              -0.93          52000
# 17   2024/12/20          53000    -100              -0.19          52700
# ..          ...            ...     ...                ...            ...
# 122  2024/07/17          86700   -1000              -1.14          87100
# 127  2024/07/10          87800       0               0.00          87600
# 128  2024/07/09          87800     400               0.46          87800
# 129  2024/07/08          87400     300               0.34          87900
# 126  2024/07/11          87600    -200              -0.23          88500
#
#      high_price  low_price  trading_volume
# 43        51800      49900        48510715
# ...

# %%
df.describe()
# Out:
#        closing_price       change  fluctutation_rate  opening_price  \
# count     245.000000   245.000000         245.000000     245.000000
# mean    70624.489796   -77.142857          -0.102571   70736.734694
# std     10666.723394  1422.754198           2.025544   10723.417264
# min     49900.000000 -8200.000000         -10.300000   50200.000000
# 25%     59200.000000  -900.000000          -1.290000   59100.000000
# 50%     74000.000000  -100.000000          -0.130000   74200.000000
# 75%     78600.000000   600.000000           0.960000   79200.000000
# max     87800.000000  4100.000000           7.210000   88500.000000
#
#          high_price     low_price  trading_volume
# count    245.000000    245.000000    2.450000e+02
# mean   71475.918367  69948.571429    2.168234e+07
# std    10650.192009  10599.619542    8.958074e+06
# min    51800.000000  49900.000000    7.805598e+06
# 25%    60000.000000  58600.000000    1.537607e+07
# 50%    74700.000000  73500.000000    1.945678e+07
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
feature = ['opening_price','high_price','low_price']


for i in feature :
  plt.scatter(data = df, x = 'date', y = feature)
  plt.xticks([])
  plt.xlabel('date')
  plt.ylabel(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-d81aca8c77b1> in <cell line: 0>()
#       3
#       4 for i in feature :
# ----> 5   plt.scatter(data = df, x = 'date', y = feature)
#       6   plt.xticks([])
#       7   plt.xlabel('date')
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3937     **kwargs,
# ...
